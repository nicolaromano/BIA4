# %%
import tensorflow.keras as keras

# %%
#image preprocessing and data augmentation using imageDataGenerator
BATCH_SIZE = 16
TARGET_SIZE = (128,128)
data_gen_args = dict(
    zoom_range=0.1,
    horizontal_flip=True,
    rescale=1./255,
    preprocessing_function=None,
)
seed=22

image_datagen = keras.preprocessing.image.ImageDataGenerator(**data_gen_args)

image_generator = image_datagen.flow_from_directory(
    "/lab/Teaching/BIA4/BIA4/Workshops/06 - Classification with CNN/ISIC2020_Small/Benign",    
    batch_size=BATCH_SIZE,
    class_mode=None,
    classes=['test'],
    seed=seed)
# Out:
# Found 7 images belonging to 1 classes.

# %%
# Out:
# array([[[[0.7253288 , 0.63513273, 0.6665053 ],
#          [0.73731524, 0.64711916, 0.6765008 ],
#          [0.74975723, 0.65956116, 0.68309057],
#          ...,
#          [0.33834687, 0.20109197, 0.17756256],
#          [0.32610255, 0.18884762, 0.17013876],
#          [0.31295922, 0.18000902, 0.16217038]],
#
#         [[0.7253288 , 0.63513273, 0.6665053 ],
#          [0.73731524, 0.64711916, 0.6765008 ],
#          [0.74975723, 0.65956116, 0.68309057],
#          ...,
#          [0.33834687, 0.20109197, 0.17756256],
#          [0.32610255, 0.18884762, 0.17013876],
#          [0.31295922, 0.18000902, 0.16217038]],
#
#         [[0.7253288 , 0.63513273, 0.6665053 ],
#          [0.73731524, 0.64711916, 0.6765008 ],
#          [0.74975723, 0.65956116, 0.68309057],
#          ...,
#          [0.33834687, 0.20109197, 0.17756256],
#          [0.32610255, 0.18884762, 0.17013876],
#          [0.31295922, 0.18000902, 0.16217038]],
#
#         ...,
#
# ...
