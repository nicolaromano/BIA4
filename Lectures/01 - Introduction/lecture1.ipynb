# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread("cells.jpg")

print(type(img))
print(f"Maximum: {np.max(img)} - Minimum {np.min(img)}")
# Out:
# <class 'numpy.ndarray'>
# Maximum: 255 - Minimum 0

# %%
plt.imshow(img)
plt.axis("off")
plt.title("HeLa cells")
plt.show()

# %%
print(img.shape)
# Out:
# (763, 800, 3)

# %%
fig, ax = plt.subplots(ncols=3, nrows=1, figsize=(12, 4))

ax[0].imshow(img[:, :, 0], cmap="gray")
ax[1].imshow(img[:, :, 1], cmap="gray")
ax[2].imshow(img[:, :, 2], cmap="gray")
ax[0].axis("off")
ax[1].axis("off")
ax[2].axis("off")
ax[0].set_title("Red channel")
ax[1].set_title("Green channel")
ax[2].set_title("Blue channel")
plt.show()

# %%
img_cropped = img[200:400, 300:400]
plt.imshow(img_cropped[75:150, 0:100])

plt.show()

# %%
np.random.seed(12345)
img = np.random.rand(6, 6)*255
img = img.astype(int)

def bmatrix(a):
    """Returns a LaTeX bmatrix

    :a: numpy array
    :returns: LaTeX bmatrix as a string
    """
    if len(a.shape) > 2:
        raise ValueError('bmatrix can at most display two dimensions')
    lines = str(a).replace('[', '').replace(']', '').splitlines()
    rv = [r'\begin{bmatrix}']
    rv += ['  ' + ' & '.join(l.split()) + r'\\' for l in lines]
    rv +=  [r'\end{bmatrix}']
    return '\n'.join(rv)

print(bmatrix(img))

plt.imshow(img, cmap="gray")
plt.axis("off")
for r in range(img.shape[0]):
    for c in range(img.shape[1]):
        color = (0, 0, 0)
        if (img[c, r] < 150):
            color = (1, 1, 1)
        plt.text(r, c, img[c, r].astype(str), ha="center", va="center", c=color, fontsize="large")

plt.rcParams["figure.figsize"] = (7, 7)
plt.show()
# Out:
# \begin{bmatrix}
#   237 & 80 & 46 & 52 & 144 & 151\\
#   245 & 166 & 190 & 166 & 190 & 245\\
#   2 & 27 & 76 & 167 & 206 & 222\\
#   245 & 184 & 163 & 182 & 119 & 83\\
#   112 & 186 & 253 & 172 & 201 & 43\\
#   6 & 204 & 230 & 6 & 125 & 134\\
# \end{bmatrix}

# %%
a = np.array([[10, 15, 20],
              [20, 25, 30],
              [120, 5, 20]])
print(bmatrix(a*2))
# Out:
# \begin{bmatrix}
#   20 & 30 & 40\\
#   40 & 50 & 60\\
#   240 & 10 & 40\\
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

img = plt.imread("cells.jpg")
plt.imshow(img)
plt.show()

# %%
from skimage import io

img = io.imread("cells.jpg")
io.imshow(img)
io.show()

# %%
img = plt.imread("nuclei1.tif")

cmaps = ["gray", "viridis", "rainbow"]

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))

for i, a in enumerate(ax):
    a.imshow(img, cmap=cmaps[i])
    a.axis("off")
    a.set_title(f"Colourmap: {cmaps[i]}")
plt.show()
